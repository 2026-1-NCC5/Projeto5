# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 150.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Z416rDUKrjAGsYnPbm5o")
project = rf.workspace("victors-workspace-on5hg").project("find-rice-bags")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Find-Rice-bags-1 in yolov8:: 100%|██████████| 23/23 [00:00<00:00, 3193.70it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import yaml

caminho_yaml = "/content/Find-Rice-bags-1/data.yaml"

with open(caminho_yaml, "r") as f:
  dados = yaml.safe_load(f)

dados['train'] = '/content/Find-Rice-bags-1/train/images'
dados['val'] = '/content/Find-Rice-bags-1/test/images'

if 'test' in dados:
  dados['test'] = '/content/Find-Rice-bags-1/test/images'

with open(caminho_yaml, 'w') as f:
  yaml.dump(dados, f)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

resultados = model.train(data="/content/Find-Rice-bags-1/data.yaml", epochs=50, imgsz=640)
# Out:
# ...
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from google.colab import files

arquivo_final = '/content/runs/detect/train/weights/best.pt'

files.download(arquivo_final)
