# %%
from ultralytics import YOLO

# Carregar o modelo Nano (ideal para o MVP)
model = YOLO('yolov8n.pt') 

# Treinar o modelo com as suas classes do Label Studio
# O treinamento vai gerar a Matriz de Confusão exigida pela disciplina [cite: 32, 127]
model.train(data=r'dataset\data.yaml', epochs=30, imgsz=640)

# Realizar uma predição para validar a identificação visual 
results = model.predict(source='dataset\images\2ba86c83-img_0030.jpg', save=True)
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\i'
# <>:11: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\dudal\AppData\Local\Temp\ipykernel_28032\3650314352.py:11: SyntaxWarning: invalid escape sequence '\i'
#   results = model.predict(source='dataset\images\2ba86c83-img_0030.jpg', save=True)
# Ultralytics 8.4.31  Python-3.13.12 torch-2.11.0+cpu CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# ...
