# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dfl1TeRkcXV6gzhzc7Em")
project = rf.workspace("dudas-workspace").project("find-rice-bags-beans-bags-and-cooking-oil-bottles")
dataset = project.version(1).download("yolov8")
